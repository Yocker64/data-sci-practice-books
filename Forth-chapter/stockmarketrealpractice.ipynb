# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import yfinance as yf

# %%
aapl = yf.Ticker("aapl")
aapl
# Out:
# yfinance.Ticker object <AAPL>

# %%
aapl_historical = aapl.history(start='2025-08-02', end='2025-08-07',interval="1m")
aapl_historical
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-08-04 09:30:00-04:00  204.505005  204.990005  204.195007  204.414993
# 2025-08-04 09:31:00-04:00  204.479996  205.669998  204.369995  205.304398
# 2025-08-04 09:33:00-04:00  205.210007  205.755402  205.020004  205.740005
# 2025-08-04 09:34:00-04:00  205.725601  205.839996  205.320007  205.479202
# 2025-08-04 09:35:00-04:00  205.479996  205.505005  205.139999  205.500000
# ...                               ...         ...         ...         ...
# 2025-08-06 15:55:00-04:00  213.410004  213.410004  212.809998  213.070007
# 2025-08-06 15:56:00-04:00  213.050003  213.089996  212.910004  212.925003
# 2025-08-06 15:57:00-04:00  212.925003  213.130005  212.889999  213.054993
# 2025-08-06 15:58:00-04:00  213.059998  213.210007  213.039993  213.134995
# 2025-08-06 15:59:00-04:00  213.134995  213.300003  213.070007  213.250000
#
#                             Volume  Dividends  Stock Splits
# ...

# %%
data = yf.download("AMZN SHOP GOOG", start="2017-01-01", end="2017-04-30",group_by="tickers")
data
# Out:
# /tmp/ipykernel_20097/2878700294.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AMZN SHOP GOOG", start="2017-01-01", end="2017-04-30",group_by="tickers")
# [*********************100%***********************]  3 of 3 completed
# Ticker       SHOP                                       AMZN             \
# Price        Open   High     Low  Close    Volume       Open       High
# Date
# 2017-01-03  4.328  4.346  4.2135  4.282   7054000  37.896000  37.938000
# 2017-01-04  4.326  4.442  4.2850  4.414   8481000  37.919498  37.984001
# 2017-01-05  4.447  4.794  4.4250  4.768  50702000  38.077499  39.119999
# 2017-01-06  4.736  4.765  4.5700  4.690  20613000  39.118000  39.972000
# 2017-01-09  4.711  4.754  4.6700  4.718   9211000  39.900002  40.088501
# ...           ...    ...     ...    ...       ...        ...        ...
# 2017-04-24  7.794  7.819  7.5200  7.583  15648000  45.433998  45.499500
# ...

# %%
aapl.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
aapl.info['forwardPE']
# Out:
# 28.012032

# %%
aapl.info['dividendRate']
# Out:
# 1.04

# %%
aapl.dividends
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2024-08-12 00:00:00-04:00    0.250000
# 2024-11-08 00:00:00-05:00    0.250000
# 2025-02-10 00:00:00-05:00    0.250000
# 2025-05-12 00:00:00-04:00    0.260000
# 2025-08-11 00:00:00-04:00    0.260000
# Name: Dividends, Length: 88, dtype: float64

# %%
import pandas as pd

tickers_list = ["aapl", "goog", "amzn", "BAC", "BA"] # example list
tickers_data= {} # empty dictionary

# %%
for ticker in tickers_list:
    ticker_object = yf.Ticker(ticker)

    #convert info() output from dictionary to dataframe
    temp = pd.DataFrame.from_dict(ticker_object.info, orient="index")
    temp.reset_index(inplace=True)
    temp.columns = ["Attribute", "Recent"]
    
    # add (ticker, dataframe) to main dictionary
    tickers_data[ticker] = temp

tickers_data
# Out:
# {'aapl':                       Attribute              Recent
#  0                      address1  One Apple Park Way
#  1                          city           Cupertino
#  2                         state                  CA
#  3                           zip               95014
#  4                       country       United States
#  ..                          ...                 ...
#  175        averageAnalystRating           2.0 - Buy
#  176  regularMarketChangePercent           -0.235719
#  177          regularMarketPrice              232.78
#  178                 displayName               Apple
#  179            trailingPegRatio              2.1195
#
#  [180 rows x 2 columns],
#  'goog':                              Attribute                     Recent
#  0                             address1  1600 Amphitheatre Parkway
#  1                                 city              Mountain View
#  2                                state                         CA
# ...

# %%
combined_data = pd.concat(tickers_data)
combined_data = combined_data.reset_index()
combined_data
# Out:
#     level_0  level_1                  Attribute              Recent
# 0      aapl        0                   address1  One Apple Park Way
# 1      aapl        1                       city           Cupertino
# 2      aapl        2                      state                  CA
# 3      aapl        3                        zip               95014
# 4      aapl        4                    country       United States
# ..      ...      ...                        ...                 ...
# 866      BA      167  exchangeTimezoneShortName                 EDT
# 867      BA      168      gmtOffSetMilliseconds           -14400000
# 868      BA      169                     market           us_market
# 869      BA      170               esgPopulated               False
# 870      BA      171           trailingPegRatio                None
#
# [871 rows x 4 columns]

# %%
del combined_data["level_1"] # clean up unnecessary column
combined_data.columns = ["Ticker", "Attribute", "Recent"] # update column names

combined_data
# Out:
#     Ticker                  Attribute              Recent
# 0     aapl                   address1  One Apple Park Way
# 1     aapl                       city           Cupertino
# 2     aapl                      state                  CA
# 3     aapl                        zip               95014
# 4     aapl                    country       United States
# ..     ...                        ...                 ...
# 866     BA  exchangeTimezoneShortName                 EDT
# 867     BA      gmtOffSetMilliseconds           -14400000
# 868     BA                     market           us_market
# 869     BA               esgPopulated               False
# 870     BA           trailingPegRatio                None
#
# [871 rows x 3 columns]

# %%
employees = combined_data[combined_data["Attribute"]=="fullTimeEmployees"].reset_index()
del employees["index"] # clean up unnecessary column

employees
# Out:
#   Ticker          Attribute   Recent
# 0   aapl  fullTimeEmployees   150000
# 1   goog  fullTimeEmployees   187103
# 2   amzn  fullTimeEmployees  1546000
# 3    BAC  fullTimeEmployees   213000
# 4     BA  fullTimeEmployees   172000

# %%
employees_untrimmed = combined_data[combined_data["Attribute"]=="fullTimeEmployees"]
employees_untrimmed
# Out:
#     Ticker          Attribute   Recent
# 14    aapl  fullTimeEmployees   150000
# 194   goog  fullTimeEmployees   187103
# 365   amzn  fullTimeEmployees  1546000
# 539    BAC  fullTimeEmployees   213000
# 713     BA  fullTimeEmployees   172000

# %%
aapl.options
# Out:
# ('2025-08-15',
#  '2025-08-22',
#  '2025-08-29',
#  '2025-09-05',
#  '2025-09-12',
#  '2025-09-19',
#  '2025-09-26',
#  '2025-10-17',
#  '2025-11-21',
#  '2025-12-19',
#  '2026-01-16',
#  '2026-02-20',
#  '2026-03-20',
#  '2026-05-15',
#  '2026-06-18',
#  '2026-09-18',
#  '2026-12-18',
#  '2027-01-15',
#  '2027-06-17',
#  '2027-12-17')

# %%
hist = aapl.history(period="max")
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098485    0.098913    0.098485    0.098485
# 1980-12-15 00:00:00-05:00    0.093775    0.093775    0.093347    0.093347
# 1980-12-16 00:00:00-05:00    0.086924    0.086924    0.086495    0.086495
# 1980-12-17 00:00:00-05:00    0.088636    0.089064    0.088636    0.088636
# 1980-12-18 00:00:00-05:00    0.091206    0.091634    0.091206    0.091206
# ...                               ...         ...         ...         ...
# 2025-08-11 00:00:00-04:00  227.919998  229.559998  224.759995  227.179993
# 2025-08-12 00:00:00-04:00  228.009995  230.800003  227.070007  229.649994
# 2025-08-13 00:00:00-04:00  231.070007  235.000000  230.429993  233.330002
# 2025-08-14 00:00:00-04:00  234.059998  235.119995  230.850006  232.779999
# 2025-08-15 00:00:00-04:00  233.729996  234.221405  229.360001  231.589996
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
aapl.splits
# Out:
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
aapl.quarterly_financials
# Out:
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.639970e-01
# Normalized EBITDA                                   3.103200e+10
# Net Income From Continuing Operation Net Minori...  2.343400e+10
# Reconciled Depreciation                             2.830000e+09
# Reconciled Cost Of Revenue                          5.031800e+10
# EBITDA                                              3.103200e+10
# EBIT                                                2.820200e+10
# Normalized Income                                   2.343400e+10
# Net Income From Continuing And Discontinued Ope...  2.343400e+10
# Total Expenses                                      6.583400e+10
# Total Operating Income As Reported                  2.820200e+10
# Diluted Average Shares                              1.494818e+10
# ...

# %%
aapl.major_holders
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.01970
# institutionsPercentHeld          0.63744
# institutionsFloatPercentHeld     0.65025
# institutionsCount             6975.00000

# %%
aapl.institutional_holders
# Out:
#   Date Reported                         Holder  pctHeld      Shares  \
# 0    2025-06-30             Vanguard Group Inc   0.0954  1415932804
# 1    2025-06-30                 Blackrock Inc.   0.0774  1148838990
# 2    2025-06-30       State Street Corporation   0.0405   601249995
# 3    2025-06-30  Geode Capital Management, LLC   0.0239   354749794
# 4    2025-06-30                       FMR, LLC   0.0207   306758594
# 5    2025-06-30        Berkshire Hathaway, Inc   0.0189   280000000
# 6    2025-03-31                 Morgan Stanley   0.0163   241221800
# 7    2025-06-30            JPMORGAN CHASE & CO   0.0145   214606399
# 8    2025-06-30  Price (T.Rowe) Associates Inc   0.0137   202720404
# 9    2025-06-30                    NORGES BANK   0.0128   189804820
#
#           Value  pctChange
# 0  327915872893     0.0108
# 1  266059617486     0.0076
# 2  139243484140     0.0088
# 3   82156503493     0.0141
# 4   71042221661    -0.0650
# 5   64845198974    -0.0667
# ...

# %%
aapl.cashflow
# Out:
#                                                   2024-09-30    2023-09-30  \
# Free Cash Flow                                  1.088070e+11  9.958400e+10
# Repurchase Of Capital Stock                    -9.494900e+10 -7.755000e+10
# Repayment Of Debt                              -9.958000e+09 -1.115100e+10
# Issuance Of Debt                                0.000000e+00  5.228000e+09
# Issuance Of Capital Stock                                NaN           NaN
# Capital Expenditure                            -9.447000e+09 -1.095900e+10
# Interest Paid Supplemental Data                          NaN  3.803000e+09
# Income Tax Paid Supplemental Data               2.610200e+10  1.867900e+10
# End Cash Position                               2.994300e+10  3.073700e+10
# Beginning Cash Position                         3.073700e+10  2.497700e+10
# Changes In Cash                                -7.940000e+08  5.760000e+09
# ...

# %%
aapl.isin
# Out:
# 'US0378331005'

# %%
hist.plot(kind="line",figsize=(12,6), subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
plt.show()

# %% [markdown]
# # Advanced Financial Data Gathering

# %% [markdown]
# ## Major Indices

# %%
import pandas as pd
import requests

# Define the URL and the header
url = "https://finance.yahoo.com/world-indices"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36'
}

# Make the request with the header
response = requests.get(url, headers=headers)

# Use pandas to read the HTML from the response text
major_indices = pd.read_html(response.text)[0]

print(major_indices.head())
# Out:
#   Symbol                           Name  Unnamed: 2  \
# 0  ^GSPC                        S&P 500         NaN
# 1   ^DJI   Dow Jones Industrial Average         NaN
# 2  ^IXIC               NASDAQ Composite         NaN
# 3   ^NYA           NYSE Composite Index         NaN
# 4   ^XAX  NYSE American Composite Index         NaN
#
#                        Price  Change Change %    Volume  Day Range  \
# 0   6,449.80 -18.74 (-0.29%)  -18.74   -0.29%    3.148B        NaN
# 1  44,946.12 +34.86 (+0.08%)   34.86   +0.08%  547.278M        NaN
# 2  21,622.98 -87.69 (-0.40%)  -87.69   -0.40%    7.367B        NaN
# 3   20,802.68 -5.74 (-0.03%)   -5.74   -0.03%         0        NaN
# 4   6,187.89 +45.22 (+0.74%)   45.22   +0.74%         0        NaN
#
#    52 Wk Range
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...

# %%
import requests

# %%
from polygon import RESTClient
import config
import json
from typing import cast
from urllib3 import HTTPResponse


client = RESTClient('xIagvEJ1Cgi9yIQRyIyu5Xhq88eUW4I8')
aggs = cast(
  HTTPResponse,
  client.get_aggs(
    'AAPL',
      1,
      'day',
      '2024-05-20',
      '2024-11-11',
      raw=True
  ),
)

data = json.loads(aggs.data)
print(data)
# Out:
# {'ticker': 'AAPL', 'queryCount': 122, 'resultsCount': 122, 'adjusted': True, 'results': [{'v': 44361275.0, 'vw': 191.0826, 'o': 189.325, 'c': 191.04, 'h': 191.9199, 'l': 189.01, 't': 1716177600000, 'n': 566908}, {'v': 42309401.0, 'vw': 192.2542, 'o': 191.09, 'c': 192.35, 'h': 192.73, 'l': 190.9201, 't': 1716264000000, 'n': 502788}, {'v': 34648547.0, 'vw': 191.4301, 'o': 192.265, 'c': 190.9, 'h': 192.8231, 'l': 190.27, 't': 1716350400000, 'n': 452377}, {'v': 51005924.0, 'vw': 188.1932, 'o': 190.98, 'c': 186.88, 'h': 191, 'l': 186.625, 't': 1716436800000, 'n': 574010}, {'v': 36326975.0, 'vw': 189.7193, 'o': 188.82, 'c': 189.98, 'h': 190.58, 'l': 188.0404, 't': 1716523200000, 'n': 492870}, {'v': 52280051.0, 'vw': 190.8169, 'o': 191.51, 'c': 189.99, 'h': 193, 'l': 189.1, 't': 1716868800000, 'n': 702191}, {'v': 53068016.0, 'vw': 191.1133, 'o': 189.61, 'c': 190.29, 'h': 192.247, 'l': 189.51, 't': 1716955200000, 'n': 603502}, {'v': 49947941.0, 'vw': 191.4032, 'o': 190.76, 'c': 191.29, 'h': 
# ...

# %%
for item in data:
    if item =='results':
        rawData=data[item]
closeList=[]
for bar in rawData:
    for category in bar:
        if category == 'c':
            closeList.append(bar[category])

print(closeList)
# Out:
# [191.04, 192.35, 190.9, 186.88, 189.98, 189.99, 190.29, 191.29, 192.25, 194.03, 194.35, 195.87, 194.48, 196.89, 193.12, 207.15, 213.07, 214.24, 212.49, 216.67, 214.29, 209.68, 207.49, 208.14, 209.07, 213.25, 214.1, 210.62, 216.75, 220.27, 221.55, 226.34, 227.82, 228.68, 232.98, 227.57, 230.54, 234.4, 234.82, 228.88, 224.18, 224.31, 223.96, 225.01, 218.54, 217.49, 217.96, 218.24, 218.8, 222.08, 218.36, 219.86, 209.27, 207.23, 209.82, 213.31, 216.24, 217.53, 221.27, 221.72, 224.72, 226.05, 225.89, 226.51, 226.4, 224.53, 226.84, 227.18, 228.03, 226.49, 229.79, 229, 222.77, 220.85, 222.38, 220.82, 220.91, 220.11, 222.66, 222.77, 222.5, 216.32, 216.79, 220.69, 228.87, 228.2, 226.47, 227.37, 226.37, 227.52, 227.79, 233, 226.21, 226.78, 225.67, 226.8, 221.69, 225.77, 229.54, 229.04, 227.55, 231.3, 233.85, 231.78, 232.15, 235, 236.48, 235.86, 230.76, 230.57, 231.41, 233.4, 233.67, 230.1, 225.91, 222.91, 222.01, 223.45, 222.72, 227.48, 226.96, 224.23]

# %%
# Out:
# {'SHELL': '/bin/bash',
#  'SESSION_MANAGER': 'local/archlinux:@/tmp/.ICE-unix/1126,unix/archlinux:/tmp/.ICE-unix/1126',
#  'WINDOWID': '94449656684208',
#  'COLORTERM': 'truecolor',
#  'XDG_CONFIG_DIRS': '/home/yocker/.config/kdedefaults:/etc/xdg',
#  'KGLOBALACCELD_PLATFORM': 'org.kde.kwin',
#  'XDG_SESSION_PATH': '/org/freedesktop/DisplayManager/Session1',
#  'XDG_MENU_PREFIX': 'plasma-',
#  'GTK_IM_MODULE': 'fcitx',
#  'CONDA_EXE': '/home/yocker/anaconda3/bin/conda',
#  '_CE_M': '',
#  'ICEAUTHORITY': '/run/user/1000/iceauth_jXdZqS',
#  'JAVA_HOME': '/usr/lib/jvm/java-24-openjdk/',
#  'MEMORY_PRESSURE_WRITE': 'c29tZSAyMDAwMDAgMjAwMDAwMAA=',
#  'POLIGONIO_API_KEY': '<hidden>',
#  'XMODIFIERS': '@im=fcitx',
#  'DESKTOP_SESSION': 'plasma',
#  'GTK_RC_FILES': '/etc/gtk/gtkrc:/home/yocker/.gtkrc:/home/yocker/.config/gtkrc',
#  'CONDA_BACKUP_QT_XCB_GL_INTEGRATION': '',
#  'XDG_SEAT': 'seat0',
#  'PWD': '/home/yocker/Documents/repos/data-science',
# ...

# %% [markdown]
# #
